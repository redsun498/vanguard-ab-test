# %% [markdown]
# # Importation of libraries thatt will be used

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as mp
import numpy as np

# %% [markdown]
# # Creation of data frames

# %%
df_demo = pd.read_csv(r"..\..\data_files\raw\df_final_demo.txt") 
df_exp = pd.read_csv(r"..\..\data_files\raw\df_final_experiment_clients.txt")
df_web_1 = pd.read_csv(r"..\..\data_files\raw\df_final_web_data_pt_1.txt")
df_web_2 = pd.read_csv(r"..\..\data_files\raw\df_final_web_data_pt_2.txt")

# %% [markdown]
# # Initial Exploratory Data Analysis (EDA)

# %%
df_demo.head(10)
# Out:
#    client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0     836976             6.0              73.0      60.5     U        2.0
# 1    2304905             7.0              94.0      58.0     U        2.0
# 2    1439522             5.0              64.0      32.0     U        2.0
# 3    1562045            16.0             198.0      49.0     M        2.0
# 4    5126305            12.0             145.0      33.0     F        2.0
# 5    3727881             5.0              71.0      30.5     U        2.0
# 6     272934             5.0              66.0      58.5     U        2.0
# 7     388801            30.0             361.0      57.5     M        5.0
# 8     285619            30.0             369.0      67.5     M        2.0
# 9    8198645            15.0             189.0      54.5     F        2.0
#
#          bal  calls_6_mnth  logons_6_mnth
# 0   45105.30           6.0            9.0
# 1  110860.30           6.0            9.0
# ...

# %%
df_demo.duplicated().sum() # no dups
# Out:
# 0

# %%
df_demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70609 entries, 0 to 70608
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   client_id         70609 non-null  int64
#  1   clnt_tenure_yr    70595 non-null  float64
#  2   clnt_tenure_mnth  70595 non-null  float64
#  3   clnt_age          70594 non-null  float64
#  4   gendr             70595 non-null  object
#  5   num_accts         70595 non-null  float64
#  6   bal               70595 non-null  float64
#  7   calls_6_mnth      70595 non-null  float64
#  8   logons_6_mnth     70595 non-null  float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 4.8+ MB

# %%
df_exp.head(10)
# Out:
#    client_id Variation
# 0    9988021      Test
# 1    8320017      Test
# 2    4033851   Control
# 3    1982004      Test
# 4    9294070   Control
# 5    9466803      Test
# 6    3170143      Test
# 7    6651403   Control
# 8    5887227      Test
# 9    2105948   Control

# %%
df_web_1.head(10)
# Out:
#    client_id            visitor_id                      visit_id process_step  \
# 0    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 1    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 2    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 3    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 4    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 5    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 6    9988021  580560515_7732621733  781255054_21935453173_531117       step_1
# 7    9988021  580560515_7732621733  781255054_21935453173_531117        start
# 8    8320017  39393514_33118319366  960651974_70596002104_312201      confirm
# 9    8320017  39393514_33118319366  960651974_70596002104_312201       step_3
#
#              date_time
# 0  2017-04-17 15:27:07
# 1  2017-04-17 15:26:51
# 2  2017-04-17 15:19:22
# ...

# %%
df_web_2.head(10)
# Out:
#    client_id             visitor_id                      visit_id  \
# 0     763412  601952081_10457207388  397475557_40440946728_419634
# 1    6019349  442094451_91531546617  154620534_35331068705_522317
# 2    6019349  442094451_91531546617  154620534_35331068705_522317
# 3    6019349  442094451_91531546617  154620534_35331068705_522317
# 4    6019349  442094451_91531546617  154620534_35331068705_522317
# 5    6019349  442094451_91531546617  154620534_35331068705_522317
# 6    4726500  934350987_45569789638  467318052_88159801968_565608
# 7    4726500  934350987_45569789638  467318052_88159801968_565608
# 8    4726500  934350987_45569789638  467318052_88159801968_565608
# 9    4726500  934350987_45569789638  467318052_88159801968_565608
#
#   process_step            date_time
# 0      confirm  2017-06-06 08:56:00
# 1      confirm  2017-06-01 11:59:27
# 2       step_3  2017-06-01 11:58:48
# 3       step_2  2017-06-01 11:58:08
# 4       step_1  2017-06-01 11:57:58
# ...

# %%
df_web_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 343141 entries, 0 to 343140
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   client_id     343141 non-null  int64
#  1   visitor_id    343141 non-null  object
#  2   visit_id      343141 non-null  object
#  3   process_step  343141 non-null  object
#  4   date_time     343141 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 13.1+ MB

# %%
df_web_2.info() # same as df_web_2
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 412264 entries, 0 to 412263
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   client_id     412264 non-null  int64
#  1   visitor_id    412264 non-null  object
#  2   visit_id      412264 non-null  object
#  3   process_step  412264 non-null  object
#  4   date_time     412264 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 15.7+ MB

# %%
df_web = pd.concat([df_web_1,df_web_2])
df_web.shape[0] == df_web_1.shape[0] + df_web_2.shape[0] # concatenated all rows
# Out:
# True

# %%
df_web.head() # client_id appears multiple times
# Out:
#    client_id            visitor_id                      visit_id process_step  \
# 0    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 1    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 2    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 3    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 4    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
#
#              date_time
# 0  2017-04-17 15:27:07
# 1  2017-04-17 15:26:51
# 2  2017-04-17 15:19:22
# 3  2017-04-17 15:19:13
# 4  2017-04-17 15:18:04

# %% [markdown]
# By the end of the first two days, we recommend you have:
#
# - Done dataset discovery: Understood the nature and structure of your datasets using Python with libraries such as Pandas, Matplotlib, and Seaborn.
# - Carried out data cleaning and fix any problems if there are any.
# - Answered the following questions about demographics:
#     - Who are the primary clients using this online process?
#    - Are the primary clients younger or older, new or long-standing?
# - Carried out a client behaviour analysis to answer any additional relevant questions you think are important.

# %%
df_exp.duplicated().sum()
# Out:
# 0

# %%
df_web_1.duplicated().sum()
# Out:
# 2095

# %%
df_web_1.loc[df_web_2.duplicated()]
# Out:
#         client_id             visitor_id                      visit_id  \
# 125        949210   591670455_4193241312   26721459_64736035042_287800
# 143       2709011  589277427_92692218515  498645027_86396077425_345948
# 326       3013805  433953983_27189934751  274365690_12489550205_303796
# 328       3013805  433953983_27189934751  274365690_12489550205_303796
# 375        522661  118624357_89874909268  474867117_79860806403_490440
# ...           ...                    ...                           ...
# 342776    8121285   381360123_2822970362  691242887_62183080121_742490
# 342778    1711767   43598821_79334691391  460912082_83091783914_500226
# 342806    4523997    70811625_8887555689  634931497_32273812861_672020
# 342998    9712277  291980727_96214119526   55270841_98068449635_455683
# 343083    4410575  558205534_85111107793   242023980_57460298323_78173
#
#        process_step            date_time
# 125          step_2  2017-04-05 19:48:26
# ...

# %%
df_web_2.loc[df_web_2.duplicated()]
# Out:
#         client_id             visitor_id                      visit_id  \
# 125       3751049  937925261_74821699083  628817270_45049432060_475841
# 143       9912156  746623513_52101087617  780044921_57678038107_984942
# 326       5786602  893139880_61416949586  747153834_69434320996_858907
# 328       5786602  893139880_61416949586  747153834_69434320996_858907
# 375       5786602  893139880_61416949586   119968876_5423296886_390511
# ...           ...                    ...                           ...
# 412120    1672289  658797407_91003097342  430110748_90347503221_597628
# 412163    4408245   14058946_73585431797  994148957_84373994761_991865
# 412165    4408245   14058946_73585431797  994148957_84373994761_991865
# 412167    4408245   14058946_73585431797  994148957_84373994761_991865
# 412217    3897324   80177429_24869309091  149796456_64325617570_112561
#
#        process_step            date_time
# 125           start  2017-05-15 23:09:44
# ...

# %%
(df_web_2.duplicated().sum() + df_web_1.duplicated().sum()) == df_web.duplicated().sum()
# Out:
# True

# %%
df_demo.isna().sum()
# Out:
# client_id            0
# clnt_tenure_yr      14
# clnt_tenure_mnth    14
# clnt_age            15
# gendr               14
# num_accts           14
# bal                 14
# calls_6_mnth        14
# logons_6_mnth       14
# dtype: int64

# %%
len(df_demo)
'''
Only 14 rows are completely null and 1 row has the clients age missing 
(we could drop the 14 rows and input a number to add to the missing value for age).
'''
# Out:
# '\nOnly 14 rows are completely null and 1 row has the clients age missing \n(we could drop the 14 rows and input a number to add to the missing value for age).\n'

# %%
df_demo
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
# ...

# %%
#Dropped rows full of Null values, we have 1 row (index = 9583) with the column clnt_age empty.
df_demo = df_demo.dropna(thresh = 3)
df_demo
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
# ...

# %%
df_demo.loc[df_demo['clnt_age'].isna()]
# Out:
#       client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 9583    4666211             8.0             106.0       NaN     F        2.0
#
#            bal  calls_6_mnth  logons_6_mnth
# 9583  42550.55           4.0            7.0

# %%
df_demo = df_demo.dropna(thresh=3)
clnt_age_mean = df_demo['clnt_age'].mean()
df_demo['clnt_age'].fillna(clnt_age_mean,inplace=True)
df_demo.isnull().sum()
# Out:
# client_id           0
# clnt_tenure_yr      0
# clnt_tenure_mnth    0
# clnt_age            0
# gendr               0
# num_accts           0
# bal                 0
# calls_6_mnth        0
# logons_6_mnth       0
# dtype: int64

# %%
df_exp.isna().sum()
# Out:
# client_id        0
# Variation    20109
# dtype: int64

# %%
(20109/70609) * 100
# Out:
# 28.479372317976466

# %%
len(df_exp)
'''
20109 values are missing for the column Variation, that represents a 28% of missing data, 
we will need to implement data imputation
'''
# Out:
# '\n20109 values are missing for the column Variation, that represents a 28% of missing data, \nwe will need to implement data imputation\n'

# %%
df_exp.duplicated(subset = 'client_id').sum()
# Out:
# 0

# %%
df_exp['Variation'].value_counts()
# Out:
# Variation
# Test       26968
# Control    23532
# Name: count, dtype: int64

# %%
df_exp.loc[df_exp['Variation'].isna()]
# Out:
#        client_id Variation
# 50500    5459747       NaN
# 50501    8031000       NaN
# 50502    1847030       NaN
# 50503    9713157       NaN
# 50504    7775828       NaN
# ...          ...       ...
# 70604    2443347       NaN
# 70605    8788427       NaN
# 70606     266828       NaN
# 70607    1266421       NaN
# 70608    9895983       NaN
#
# [20109 rows x 2 columns]

# %%
df_web.isna().sum()
'''
No missing values. 
'''
# Out:
# '\nNo missing values. \n'

# %%
df_exp
# Out:
#        client_id Variation
# 0        9988021      Test
# 1        8320017      Test
# 2        4033851   Control
# 3        1982004      Test
# 4        9294070   Control
# ...          ...       ...
# 70604    2443347       NaN
# 70605    8788427       NaN
# 70606     266828       NaN
# 70607    1266421       NaN
# 70608    9895983       NaN
#
# [70609 rows x 2 columns]

# %%
df_exp.dropna(inplace=True)
df_exp
# Out:
#        client_id Variation
# 0        9988021      Test
# 1        8320017      Test
# 2        4033851   Control
# 3        1982004      Test
# 4        9294070   Control
# ...          ...       ...
# 50495     393005   Control
# 50496    2908510   Control
# 50497    7230446      Test
# 50498    5230357      Test
# 50499    6334360      Test
#
# [50500 rows x 2 columns]

# %%
df_demo
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
# ...

# %%
df_web
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 412259    9668240   388766751_9038881013   922267647_3096648104_968866
# 412260    9668240   388766751_9038881013   922267647_3096648104_968866
# 412261    9668240   388766751_9038881013   922267647_3096648104_968866
# 412262    9668240   388766751_9038881013   922267647_3096648104_968866
# 412263     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time
# 0            step_3  2017-04-17 15:27:07
# ...

# %% [markdown]
# Who are the primary clients using this online process?
#
# Are the primary clients younger or older, new or long-standing?

# %%
df_demo
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
# ...

# %%
df_demo.describe()
# Out:
#           client_id  clnt_tenure_yr  clnt_tenure_mnth      clnt_age  \
# count  7.059500e+04    70595.000000      70595.000000  70595.000000
# mean   5.005021e+06       12.052950        150.659367     46.442240
# std    2.877269e+06        6.871819         82.089854     15.591162
# min    1.690000e+02        2.000000         33.000000     13.500000
# 25%    2.519604e+06        6.000000         82.000000     32.500000
# 50%    5.016969e+06       11.000000        136.000000     47.000000
# 75%    7.483064e+06       16.000000        192.000000     59.000000
# max    9.999839e+06       62.000000        749.000000     96.000000
#
#           num_accts           bal  calls_6_mnth  logons_6_mnth
# count  70595.000000  7.059500e+04  70595.000000   70595.000000
# mean       2.255528  1.474452e+05      3.382478       5.566740
# std        0.534997  3.015087e+05      2.236580       2.353286
# min        1.000000  1.378942e+04      0.000000       1.000000
# ...

# %%
df_demo['clnt_age'].value_counts()
# Out:
# clnt_age
# 58.50000    859
# 55.50000    830
# 29.50000    829
# 28.50000    827
# 57.50000    826
#            ...
# 14.00000      2
# 46.44224      1
# 94.50000      1
# 95.50000      1
# 13.50000      1
# Name: count, Length: 166, dtype: int64

# %%
df_demo.describe(include = 'object')
# Out:
#         gendr
# count   70595
# unique      4
# top         U
# freq    24122

# %%
#X appears to be a mistake 
df_demo['gendr'].value_counts().sort_values(ascending = False)
# Out:
# gendr
# U    24122
# M    23724
# F    22746
# X        3
# Name: count, dtype: int64

# %% [markdown]
# Using the complete demographic information:
#
# The main clientelle using this procces are people from the ages 32-59 with an average of 46. The genders of the users are pretty evenly split between U (undiceded) with a 34%, M (Male) with a 34% and F (Female) with a 32%.
#
# The primary clients are long standing, with an average of 12 years of tenure for their contracts

# %%
#
df_web_demo = pd.merge(left = df_web, right =df_demo, on = 'client_id')

# %%
df_web_demo
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 449711    9895983  473024645_56027518531  498981662_93503779869_272484
# 449712    9895983  473024645_56027518531  498981662_93503779869_272484
# 449713    9895983  473024645_56027518531  498981662_93503779869_272484
# 449714    9895983  473024645_56027518531  498981662_93503779869_272484
# 449715    9895983  473024645_56027518531  498981662_93503779869_272484
#
#        process_step            date_time  clnt_tenure_yr  clnt_tenure_mnth  \
# ...

# %%
df_web_demo.groupby('gendr')['visit_id'].count().sort_values(ascending= False)
# Out:
# gendr
# M    151877
# U    151608
# F    146217
# X        14
# Name: visit_id, dtype: int64

# %%
df_web_demo.groupby('client_id')['client_id'].count().sort_values(ascending= False)
# Out:
# client_id
# 5574879    111
# 2274658     90
# 2128341     84
# 5951379     81
# 1595223     81
#           ...
# 1171635      1
# 2050747      1
# 689760       1
# 4058987      1
# 674205       1
# Name: client_id, Length: 70595, dtype: int64

# %%
df_web['client_id'].value_counts().head(10)
# Out:
# client_id
# 5574879    111
# 2274658     90
# 2128341     84
# 5951379     81
# 1595223     81
# 1952790     80
# 9800867     75
# 7733877     72
# 465007      72
# 3545814     72
# Name: count, dtype: int64

# %%
df_exp.count()
# Out:
# client_id    50500
# Variation    50500
# dtype: int64

# %%
df_demo.isnull().sum()
# Out:
# client_id           0
# clnt_tenure_yr      0
# clnt_tenure_mnth    0
# clnt_age            0
# gendr               0
# num_accts           0
# bal                 0
# calls_6_mnth        0
# logons_6_mnth       0
# dtype: int64

# %%
df_online = pd.merge(df_demo,df_exp,how='left',on='client_id')

# %%
df_online.dropna(inplace=True)

# %%
df_online.isnull().sum()
# Out:
# client_id           0
# clnt_tenure_yr      0
# clnt_tenure_mnth    0
# clnt_age            0
# gendr               0
# num_accts           0
# bal                 0
# calls_6_mnth        0
# logons_6_mnth       0
# Variation           0
# dtype: int64

# %%
df_online.describe()
# Out:
#           client_id  clnt_tenure_yr  clnt_tenure_mnth      clnt_age  \
# count  5.048800e+04    50488.000000      50488.000000  50488.000000
# mean   5.006173e+06       12.031730        150.415485     47.319778
# std    2.877417e+06        6.860282         81.944830     15.518463
# min    5.550000e+02        2.000000         33.000000     17.000000
# 25%    2.515700e+06        6.000000         82.000000     33.500000
# 50%    5.025026e+06       11.000000        136.000000     48.000000
# 75%    7.477918e+06       16.000000        192.000000     59.500000
# max    9.999832e+06       55.000000        669.000000     96.000000
#
#           num_accts           bal  calls_6_mnth  logons_6_mnth
# count  50488.000000  5.048800e+04  50488.000000   50488.000000
# mean       2.254575  1.495147e+05      3.093289       6.131873
# std        0.533671  3.020364e+05      2.187991       2.175423
# min        1.000000  2.378944e+04      0.000000       3.000000
# ...

# %%
#All the values within the df_web dataset are within the period of time that the experiment was set in place 
#3/15/2017 to 6/20/2017
df_web.sort_values(by='date_time', key=lambda x: pd.to_datetime(x))
# Out:
#         client_id             visitor_id                      visit_id  \
# 286566    9088444  242404224_96732670250  423038079_46067236368_400417
# 35293     7179755  167765295_97487764427   264484508_5982901710_928530
# 35292     7179755  167765295_97487764427   264484508_5982901710_928530
# 35291     7179755  167765295_97487764427   264484508_5982901710_928530
# 35290     7179755  167765295_97487764427   264484508_5982901710_928530
# ...           ...                    ...                           ...
# 176132    4159912  169591677_18042085072  358114812_31313949217_790854
# 176131    4159912  169591677_18042085072  358114812_31313949217_790854
# 176130    4159912  169591677_18042085072  358114812_31313949217_790854
# 184010    5640210  854970757_75895258102  959123368_90077952691_695747
# 327563    4227031   375803585_1924749079  694062705_73082073487_259240
#
#        process_step            date_time
# 286566       step_3  2017-03-15 00:03:03
# ...

# %%
df_web.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 755405 entries, 0 to 412263
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   client_id     755405 non-null  int64
#  1   visitor_id    755405 non-null  object
#  2   visit_id      755405 non-null  object
#  3   process_step  755405 non-null  object
#  4   date_time     755405 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 34.6+ MB

# %% [markdown]
# **Completion Rate**

# %%
confirm_step_count = df_web[df_web['process_step'] == 'confirm']['client_id'].nunique()
total_users = df_web['client_id'].nunique()
completion_rate = confirm_step_count / total_users
print(f"Completion Rate: {completion_rate:.2%}")
# Out:
# Completion Rate: 67.53%

# %%
df_ab = pd.merge(df_online,df_web)

df_exp.isnull().sum()
# Out:
# client_id    0
# Variation    0
# dtype: int64

# %%
df_ab
# Out:
#         client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  \
# 0          836976             6.0              73.0      60.5     U
# 1          836976             6.0              73.0      60.5     U
# 2          836976             6.0              73.0      60.5     U
# 3          836976             6.0              73.0      60.5     U
# 4          836976             6.0              73.0      60.5     U
# ...           ...             ...               ...       ...   ...
# 321202    7468138            18.0             222.0      61.0     F
# 321203    7468138            18.0             222.0      61.0     F
# 321204    7468138            18.0             222.0      61.0     F
# 321205    7468138            18.0             222.0      61.0     F
# 321206    7468138            18.0             222.0      61.0     F
#
#         num_accts        bal  calls_6_mnth  logons_6_mnth Variation  \
# 0             2.0   45105.30           6.0            9.0      Test
# ...

# %%
df_ab['date_time'] = pd.to_datetime(df_ab['date_time'], errors='coerce')

# %%
df_ab.dtypes
# Out:
# client_id                    int64
# clnt_tenure_yr             float64
# clnt_tenure_mnth           float64
# clnt_age                   float64
# gendr                       object
# num_accts                  float64
# bal                        float64
# calls_6_mnth               float64
# logons_6_mnth              float64
# Variation                   object
# visitor_id                  object
# visit_id                    object
# process_step                object
# date_time           datetime64[ns]
# dtype: object

# %%
df_ab = df_ab.sort_values(['client_id','date_time'])

# %%
mask = df_ab['Variation'] == 'Test'
df_test = df_ab.loc[mask]
df_control = df_ab.loc[~mask]

# %%
df_test
# Out:
#         client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  \
# 255408        555             3.0              46.0      29.5     U
# 255407        555             3.0              46.0      29.5     U
# 255406        555             3.0              46.0      29.5     U
# 255405        555             3.0              46.0      29.5     U
# 255404        555             3.0              46.0      29.5     U
# ...           ...             ...               ...       ...   ...
# 310107    9999729            10.0             124.0      31.0     F
# 310106    9999729            10.0             124.0      31.0     F
# 310105    9999729            10.0             124.0      31.0     F
# 51309     9999832            23.0             281.0      49.0     F
# 51308     9999832            23.0             281.0      49.0     F
#
#         num_accts        bal  calls_6_mnth  logons_6_mnth Variation  \
# 255408        2.0   25454.66           2.0            6.0      Test
# ...

# %%
df_control
# Out:
#         client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  \
# 302427       1028            12.0             145.0      36.0     M
# 302426       1028            12.0             145.0      36.0     M
# 302425       1028            12.0             145.0      36.0     M
# 302424       1028            12.0             145.0      36.0     M
# 302423       1028            12.0             145.0      36.0     M
# ...           ...             ...               ...       ...   ...
# 142971    9998346            50.0             602.0      61.5     F
# 142968    9998346            50.0             602.0      61.5     F
# 142969    9998346            50.0             602.0      61.5     F
# 142970    9998346            50.0             602.0      61.5     F
# 27192     9998921            15.0             189.0      38.0     F
#
#         num_accts        bal  calls_6_mnth  logons_6_mnth Variation  \
# 302427        3.0  103520.22           1.0            4.0   Control
# ...

# %%
# completion rate from Test - The proportion of users who reach the final ‘confirm’ step. Using client_id since its
# the unique id of the client
confirm_step_count_tst = df_test[df_test['process_step'] == 'confirm']['client_id'].nunique()
total_users_tst = df_test['client_id'].nunique()
completion_rate = confirm_step_count / total_users
print(f"Completion Rate: {completion_rate:.2%}")
# Out:
# Completion Rate: 69.29%

# %%
import statsmodels.api as sm

# %%
Null Hypothesis:
    
Alternative Hypothesis:

# %%
stat, p_value = sm.stats.proportions_ztest([confirm_step_count_ctl, confirm_step_count_tst], [total_users_ctl, total_users_tst])

# %%
stat, p_value
# Out:
# (-8.889390699380462, 6.144491429497383e-19)

# %%
df_control['process_step'].value_counts()
# Out:
# process_step
# start      47594
# step_1     29659
# step_2     25879
# step_3     22789
# confirm    17499
# Name: count, dtype: int64

# %%
confirm_step_count_ctl = df_control[df_control['process_step'] == 'confirm']['client_id'].nunique()
total_users_ctl = df_control['client_id'].nunique()
completion_rate_ctl = confirm_step_count_ctl / total_users_ctl
print(f"Completion Rate: {completion_rate_ctl:.2%}")
# Out:
# Completion Rate: 65.58%

# %%
#creation for test
#df_ab['completed'] = df_ab['process_step'] == 'confirm'

# %%
#pd.crosstab(df_ab['completed'],df_ab['Variation'], df_ab['client_id'], aggfunc=pd.Series.nunique)

# %%
df_ab

# %%
df_test

# %%
df_control

# %%
df_test['first_time']= df_test.groupby('client_id')['date_time'].shift(1)

# %%
df_test['first_time'].isnull().sum()

# %%
 df_test['diff'] = df_test['date_time']-df_test['first_time']

# %%
df_test['diff'].sort_values()

# %%
df_test.groupby('process_step')['diff'].mean()

# %%
df_control['first_time']= df_control.groupby('client_id')['date_time'].shift(1)

# %%
df_control['first_time'].isnull().sum()

# %%
df_control['diff'] = df_control['date_time']-df_control['first_time']

# %%
df_control.groupby('process_step')['diff'].mean()

# %% [markdown]
# Null Hypothesis: There is no difference between the completion rate for the Test and Control groups
#
# Alternitive Hypothesis: There **_is_** a difference between the completion rate for the Test and Control groups

# %% [markdown]
# # t test for two groups

# %%
x =1
